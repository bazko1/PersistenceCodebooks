# %%
import sys
sys.path.insert(0, "../..")

# %%
import numpy as np
import scipy.io
from gudhi.representations.preprocessing import BirthPersistenceTransform, DiagramScaler
from sklearn.preprocessing import MaxAbsScaler, MinMaxScaler
from sklearn.pipeline import make_pipeline
from preprocessing import *
from visualization import *

# %%
data_path = "./exp03_pds.mat"
data_mat = scipy.io.loadmat(data_path)
data = data_mat["pds"]

# %%
data = data.ravel()

y = []
for label, diagram in enumerate(data):
    diagram = diagram.ravel()
    y += len(diagram) * [label]
y = np.array(y)

X = np.concatenate(data)
X = np.concatenate(X)

pipe = make_pipeline(BirthPersistenceTransform(), 
               DiagramScaler(use=True, 
                             scalers=[
                                 ((0,), MinMaxScaler(copy=False)),
                                 ((1,), MinMaxScaler(copy=False))]))

preprocessed = np.array(pipe.fit_transform(X, y))

# %%
all_points = np.concatenate(preprocessed)
plt.title("Full data")
plt.scatter(all_points[:, 0], all_points[:, 1], s=0.5)

# %% [markdown]
# # Visualization of random sampler with different weight functions

# %%
#Different persistence weighting functions visualization
sampling_weights = {
    "const": None,
    "lin" : lambda x : x[1],
    "root2" : lambda x : x[1]**(1/2),
    "root3" : lambda x : x[1]**(1/2),
    "pow2" : lambda x : x[1]**2,
    "pow3" : lambda x : x[1]**3,
}

index = 1
fig = plt.figure(figsize=(12,6))

for name, weight in sampling_weights.items():
    transformed = RandomPDSampler(50000, weight, random_state=42).fit_transform(preprocessed, y)[0]
    
    ax = fig.add_subplot(2,3,index)
    ax.set_title(name)
    ax.scatter(transformed[:, 0], transformed[:, 1], s=0.5)
    #ax.set_ylim(0,1)
    #ax.set_xlim(0,1)
    
    index += 1
    
fig.tight_layout(pad=1.0)

# %% [markdown]
# # Visualization of grid sampler with different weight functions

# %%
sampling_weights = {
    "const": None,
    "lin" : lambda x : x[1],
    "root2" : lambda x : x[1]**(1/2),
    "root3" : lambda x : x[1]**(1/2),
    "pow2" : lambda x : x[1]**2,
    "pow3" : lambda x : x[1]**3,
}

index = 1
fig = plt.figure(figsize=(12,6))

for name, weight in sampling_weights.items():
    transformed = GridPDSampler((25,25), 500, weight, random_state=42).fit_transform(preprocessed, y)[0]
    
    ax = fig.add_subplot(2,3,index)
    ax.set_title(name)
    ax.scatter(transformed[:, 0], transformed[:, 1], s=0.5)
    #ax.set_ylim(0,1)
    #ax.set_xlim(0,1)
    
    index += 1
    
fig.tight_layout(pad=1.0)
